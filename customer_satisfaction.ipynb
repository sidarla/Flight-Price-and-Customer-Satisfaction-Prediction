# %%
import pandas as pd
df=pd.read_csv("customer_Satisfaction.csv")
df
# Out:
# c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df['Arrival Delay in Minutes'].isna().sum()
# Out:
# 310

# %%
df.fillna(method='ffill',inplace=True)
df.fillna(method='bfill',inplace=True)
df.isna().sum()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15076\3206476230.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15076\3206476230.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',inplace=True)
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# ...

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
category={'Male':1,'Female':0}
df['Gender']=df['Gender'].map(category)

# %%
df['Gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    52727
# 1    51177
# Name: count, dtype: int64

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
model=LabelEncoder()
df['Customer Type']=model.fit_transform(df['Customer Type'])

# %%
df
# Out:
#         Unnamed: 0      id  Gender  Customer Type  Age   Type of Travel  \
# 0                0   70172       1              0   13  Personal Travel
# 1                1    5047       1              1   25  Business travel
# 2                2  110028       0              0   26  Business travel
# 3                3   24026       0              0   25  Business travel
# 4                4  119299       1              0   61  Business travel
# ...            ...     ...     ...            ...  ...              ...
# 103899      103899   94171       0              1   23  Business travel
# 103900      103900   73097       1              0   49  Business travel
# 103901      103901   68825       1              1   30  Business travel
# 103902      103902   54173       0              1   22  Business travel
# 103903      103903   62567       1              0   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# ...

# %%
df['Class']=model.fit_transform(df['Class'])
df['Type of Travel']=model.fit_transform(df['Type of Travel'])
df
# Out:
#         Unnamed: 0      id  Gender  Customer Type  Age  Type of Travel  Class  \
# 0                0   70172       1              0   13               1      2
# 1                1    5047       1              1   25               0      0
# 2                2  110028       0              0   26               0      0
# 3                3   24026       0              0   25               0      0
# 4                4  119299       1              0   61               0      0
# ...            ...     ...     ...            ...  ...             ...    ...
# 103899      103899   94171       0              1   23               0      1
# 103900      103900   73097       1              0   49               0      0
# 103901      103901   68825       1              1   30               0      0
# 103902      103902   54173       0              1   22               0      1
# 103903      103903   62567       1              0   27               0      0
#
# ...

# %%
df=pd.get_dummies(df,columns=['satisfaction'],dtype='int',drop_first=True)

# %%
df
# Out:
#         Unnamed: 0      id  Gender  Customer Type  Age  Type of Travel  Class  \
# 0                0   70172       1              0   13               1      2
# 1                1    5047       1              1   25               0      0
# 2                2  110028       0              0   26               0      0
# 3                3   24026       0              0   25               0      0
# 4                4  119299       1              0   61               0      0
# ...            ...     ...     ...            ...  ...             ...    ...
# 103899      103899   94171       0              1   23               0      1
# 103900      103900   73097       1              0   49               0      0
# 103901      103901   68825       1              1   30               0      0
# 103902      103902   54173       0              1   22               0      1
# 103903      103903   62567       1              0   27               0      0
#
# ...

# %%
df['satisfaction_satisfied'].unique()
# Out:
# array([0, 1])

# %%
df['satisfaction_satisfied'].value_counts()
# Out:
# satisfaction_satisfied
# 0    58879
# 1    45025
# Name: count, dtype: int64

# %%
df['satisfaction_satisfied'].value_counts(normalize=True)
# Out:
# satisfaction_satisfied
# 0    0.566667
# 1    0.433333
# Name: proportion, dtype: float64

# %%
# %pip install --upgrade scikit-learn imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#         Unnamed: 0      id  Gender  Customer Type  Age  Type of Travel  Class  \
# 0                0   70172       1              0   13               1      2
# 1                1    5047       1              1   25               0      0
# 2                2  110028       0              0   26               0      0
# 3                3   24026       0              0   25               0      0
# 4                4  119299       1              0   61               0      0
# ...            ...     ...     ...            ...  ...             ...    ...
# 103899      103899   94171       0              1   23               0      1
# 103900      103900   73097       1              0   49               0      0
# 103901      103901   68825       1              1   30               0      0
# 103902      103902   54173       0              1   22               0      1
# 103903      103903   62567       1              0   27               0      0
#
# ...

# %%
#from imblearn.over_sampling import RandomOverSampler
#from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
x=df.drop(['satisfaction_satisfied','Unnamed: 0'],axis=1)
y=df['satisfaction_satisfied']
ros=SMOTE(k_neighbors=3)
#ros=RandomOverSampler()
#ros=RandomUnderSampler()
x_new,y_new=ros.fit_resample(x,y)
data=x_new
data['satisfaction_satisfied']=y_new

# %%
data.drop(["id"],axis=1,inplace=True)

# %%
data
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            1              0   13               1      2              460
# 1            1              1   25               0      0              235
# 2            0              0   26               0      0             1142
# 3            0              0   25               0      0              562
# 4            1              0   61               0      0              214
# ...        ...            ...  ...             ...    ...              ...
# 117753       0              0   34               0      0             1671
# 117754       0              0   45               0      0              109
# 117755       0              0   20               0      0              614
# 117756       0              0   33               0      0             1022
# 117757       0              0   40               0      0             2845
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
sns.heatmap(x.corr(), annot=True, cmap='coolwarm', linewidths=0.1,)
plt.show()

# %%
data['satisfaction_satisfied'].value_counts()
# Out:
# satisfaction_satisfied
# 0    58879
# 1    58879
# Name: count, dtype: int64

# %%
data['satisfaction_satisfied'].value_counts(normalize=True)
# Out:
# satisfaction_satisfied
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
import pandas as pd
import  numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
x=data.drop(['satisfaction_satisfied'],axis=1)
y=data['satisfaction_satisfied']
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.1)
models = [LogisticRegression(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier(),AdaBoostClassifier(),RandomForestClassifier(),GradientBoostingClassifier()]
accu= 0
best_algo = None
for model in models:
    model.fit(x_train,y_train)
    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)
    print(f"Model: {type(model).__name__}")
    print("*******Train*******")
    print(f"Accuracy Score: {accuracy_score(y_train,train_pred)}")
    print(f"Precision Score: {precision_score(y_train,train_pred,average='micro')}")
    print(f"Recall score: {recall_score(y_train,train_pred,average='micro')}")
    print(f"F1 Score: {f1_score(y_train,train_pred,average='micro')}")
    print("********Test********")
    print(f"Accuracy Score: {accuracy_score(y_test,test_pred)}")
    print(f"Precision Score: {precision_score(y_test,test_pred,average='micro')}")
    print(f"Recall score: {recall_score(y_test,test_pred,average='micro')}")
    print(f"F1 Score: {f1_score(y_test,test_pred,average='micro')}")
    print("\n")
    if accuracy_score(y_test,test_pred)>accu:
        best_algo =type(model).__name__ 
        accu= accuracy_score(y_test,test_pred)
best_algo
# Out:
# c:\Users\Dell\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model: LogisticRegression
# *******Train*******
# Accuracy Score: 0.801353059953577
# Precision Score: 0.801353059953577
# Recall score: 0.801353059953577
# F1 Score: 0.801353059953577
# ********Test********
# Accuracy Score: 0.8070652173913043
# Precision Score: 0.8070652173913043
# Recall score: 0.8070652173913043
# F1 Score: 0.8070652173913043
#
#
# Model: KNeighborsClassifier
# *******Train*******
# Accuracy Score: 0.8334622860485743
# ...

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
import joblib

joblib.dump(model, 'modelv2.joblib')
# Out:
# ['modelv2.joblib']

# %%
loaded_model = joblib.load('modelv2.joblib')

# Test the loaded model
predictions = loaded_model.predict(x_test)
print(predictions)
# Out:
# [1 0 0 ... 0 1 1]
