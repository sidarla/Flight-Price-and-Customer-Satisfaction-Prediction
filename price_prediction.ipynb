# %%
import pandas as pd
df=pd.read_csv('Flight_Price.csv') 
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)
df.fillna(method='bfill',inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5916\2847704913.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5916\2847704913.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',inplace=True)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3492
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df['Additional_Info'].value_counts()
# Out:
# Additional_Info
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %%
df['Additional_Info'] = df['Additional_Info'].str.lower()

# %%
df['Additional_Info'].value_counts()
# Out:
# Additional_Info
# no info                         8348
# in-flight meal not included     1982
# no check-in baggage included     320
# 1 long layover                    19
# change airports                    7
# business class                     4
# 1 short layover                    1
# red-eye flight                     1
# 2 long layover                     1
# Name: count, dtype: int64

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3492
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Airline']=le.fit_transform(df['Airline'])
df['Source']=le.fit_transform(df['Source'])
df['Additional_Info']=le.fit_transform(df['Additional_Info'])
df['Destination']=le.fit_transform(df['Destination'])
df['Total_Stops']=le.fit_transform(df['Total_Stops'])
df
# Out:
#        Airline Date_of_Journey  Source  Destination                  Route  \
# 0            3      24/03/2019       0            5              BLR ? DEL
# 1            1       1/05/2019       3            0  CCU ? IXR ? BBI ? BLR
# 2            4       9/06/2019       2            1  DEL ? LKO ? BOM ? COK
# 3            3      12/05/2019       3            0        CCU ? NAG ? BLR
# 4            3      01/03/2019       0            5        BLR ? NAG ? DEL
# ...        ...             ...     ...          ...                    ...
# 10678        0       9/04/2019       3            0              CCU ? BLR
# 10679        1      27/04/2019       3            0              CCU ? BLR
# 10680        4      27/04/2019       0            2              BLR ? DEL
# 10681       10      01/03/2019       0            5              BLR ? DEL
# 10682        1       9/05/2019       2            1  DEL ? GOI ? BOM ? COK
#
# ...

# %%
#checking how many unique names are there in the column
df['Route'].unique()
# Out:
# array(['BLR ? DEL', 'CCU ? IXR ? BBI ? BLR', 'DEL ? LKO ? BOM ? COK',
#        'CCU ? NAG ? BLR', 'BLR ? NAG ? DEL', 'CCU ? BLR',
#        'BLR ? BOM ? DEL', 'DEL ? BOM ? COK', 'DEL ? BLR ? COK',
#        'MAA ? CCU', 'CCU ? BOM ? BLR', 'DEL ? AMD ? BOM ? COK',
#        'DEL ? PNQ ? COK', 'DEL ? CCU ? BOM ? COK', 'BLR ? COK ? DEL',
#        'DEL ? IDR ? BOM ? COK', 'DEL ? LKO ? COK',
#        'CCU ? GAU ? DEL ? BLR', 'DEL ? NAG ? BOM ? COK',
#        'CCU ? MAA ? BLR', 'DEL ? HYD ? COK', 'CCU ? HYD ? BLR',
#        'DEL ? COK', 'CCU ? DEL ? BLR', 'BLR ? BOM ? AMD ? DEL',
#        'BOM ? DEL ? HYD', 'DEL ? MAA ? COK', 'BOM ? HYD',
#        'DEL ? BHO ? BOM ? COK', 'DEL ? JAI ? BOM ? COK',
#        'DEL ? ATQ ? BOM ? COK', 'DEL ? JDH ? BOM ? COK',
#        'CCU ? BBI ? BOM ? BLR', 'BLR ? MAA ? DEL',
#        'DEL ? GOI ? BOM ? COK', 'DEL ? BDQ ? BOM ? COK',
#        'CCU ? JAI ? BOM ? BLR', 'CCU ? BBI ? BLR', 'BLR ? HYD ? DEL',
#        'DEL ? TRV ? COK', 'CCU ? IXR ? DEL ? BLR',
# ...

# %%
df.drop(columns=['Route'],inplace=True)

# %%
#convert Date_of_Journey to day,month,year
df['Date']=pd.to_datetime(df['Date_of_Journey'],format='%d/%m/%Y').dt.day
df['Month']=pd.to_datetime(df['Date_of_Journey'],format='%d/%m/%Y').dt.month
df['Year']=pd.to_datetime(df['Date_of_Journey'],format='%d/%m/%Y').dt.year
df.drop(['Date_of_Journey'],axis=1,inplace=True)
df
# Out:
#        Airline  Source  Destination Dep_Time  Arrival_Time Duration  \
# 0            3       0            5    22:20  01:10 22 Mar   2h 50m
# 1            1       3            0    05:50         13:15   7h 25m
# 2            4       2            1    09:25  04:25 10 Jun      19h
# 3            3       3            0    18:05         23:30   5h 25m
# 4            3       0            5    16:50         21:35   4h 45m
# ...        ...     ...          ...      ...           ...      ...
# 10678        0       3            0    19:55         22:25   2h 30m
# 10679        1       3            0    20:45         23:20   2h 35m
# 10680        4       0            2    08:20         11:20       3h
# 10681       10       0            5    11:30         14:10   2h 40m
# 10682        1       2            1    10:55         19:15   8h 20m
#
#        Total_Stops  Additional_Info  Price  Date  Month  Year
# 0                4                7   3897    24      3  2019
# ...

# %%
df
# Out:
#        Airline  Source  Destination Dep_Time  Arrival_Time Duration  \
# 0            3       0            5    22:20  01:10 22 Mar   2h 50m
# 1            1       3            0    05:50         13:15   7h 25m
# 2            4       2            1    09:25  04:25 10 Jun      19h
# 3            3       3            0    18:05         23:30   5h 25m
# 4            3       0            5    16:50         21:35   4h 45m
# ...        ...     ...          ...      ...           ...      ...
# 10678        0       3            0    19:55         22:25   2h 30m
# 10679        1       3            0    20:45         23:20   2h 35m
# 10680        4       0            2    08:20         11:20       3h
# 10681       10       0            5    11:30         14:10   2h 40m
# 10682        1       2            1    10:55         19:15   8h 20m
#
#        Total_Stops  Additional_Info  Price  Date  Month  Year
# 0                4                7   3897    24      3  2019
# ...

# %%
#convert Duration into hours and minutes
df['Duration_hours']=df['Duration'].str.extract('(\d+)h').fillna(0).astype(int)
df['Duration_minutes']=df['Duration'].str.extract('(\d+)m').fillna(0).astype(int)
df.drop(['Duration'],axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination Dep_Time  Arrival_Time  Total_Stops  \
# 0            3       0            5    22:20  01:10 22 Mar            4
# 1            1       3            0    05:50         13:15            1
# 2            4       2            1    09:25  04:25 10 Jun            1
# 3            3       3            0    18:05         23:30            0
# 4            3       0            5    16:50         21:35            0
# ...        ...     ...          ...      ...           ...          ...
# 10678        0       3            0    19:55         22:25            4
# 10679        1       3            0    20:45         23:20            4
# 10680        4       0            2    08:20         11:20            4
# 10681       10       0            5    11:30         14:10            4
# 10682        1       2            1    10:55         19:15            1
#
#        Additional_Info  Price  Date  Month  Year  Duration_hours  \
# ...

# %%
df['Departure_hour']=df['Dep_Time'].str.extract('(\d+):').astype(int)
df['Departure_minute']=df['Dep_Time'].str.extract(':(\d+)').astype(int)
df.drop(['Dep_Time'],axis=1,inplace=True)

# %%
df
# Out:
#        Airline  Source  Destination  Arrival_Time  Total_Stops  \
# 0            3       0            5  01:10 22 Mar            4
# 1            1       3            0         13:15            1
# 2            4       2            1  04:25 10 Jun            1
# 3            3       3            0         23:30            0
# 4            3       0            5         21:35            0
# ...        ...     ...          ...           ...          ...
# 10678        0       3            0         22:25            4
# 10679        1       3            0         23:20            4
# 10680        4       0            2         11:20            4
# 10681       10       0            5         14:10            4
# 10682        1       2            1         19:15            1
#
#        Additional_Info  Price  Date  Month  Year  Duration_hours  \
# 0                    7   3897    24      3  2019               2
# 1                    7   7662     1      5  2019               7
# ...

# %%
df['Arrival_hour']=df['Arrival_Time'].str.extract('(\d+):').astype(int)
df['Arrival_minute']=df['Arrival_Time'].str.extract(':(\d+)').astype(int)
df.drop(['Arrival_Time'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Total_Stops         0
# Additional_Info     0
# Price               0
# Date                0
# Month               0
# Year                0
# Duration_hours      0
# Duration_minutes    0
# Departure_hour      0
# Departure_minute    0
# Arrival_hour        0
# Arrival_minute      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Price', 'Date', 'Month', 'Year', 'Duration_hours', 'Duration_minutes',
#        'Departure_hour', 'Departure_minute', 'Arrival_hour', 'Arrival_minute'],
#       dtype='object')

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            3       0            5            4                7   3897
# 1            1       3            0            1                7   7662
# 2            4       2            1            1                7  13882
# 3            3       3            0            0                7   6218
# 4            3       0            5            0                7  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        0       3            0            4                7   4107
# 10679        1       3            0            4                7   4145
# 10680        4       0            2            4                7   7229
# 10681       10       0            5            4                7  12648
# 10682        1       2            1            1                7  11753
#
#        Date  Month  Year  Duration_hours  Duration_minutes  Departure_hour  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()

# %%
mid = df['Price'].median()
Q1 = df[df['Price']<mid]
Q2 = df[df['Price']>mid]
Q1_mid = Q1['Price'].median()
Q2_mid = Q2['Price'].median()

IQR = Q2_mid-Q1_mid
l_f = Q1_mid-1.5*IQR
u_f = Q2_mid+1.5*IQR
data = df[(df['Price']>=l_f) & (df['Price']<=u_f)]

min = data['Price'].min()
max =data['Price'].max()
avg = data['Price'].mean()
std = data['Price'].std()
data['price_norm'] = (data['Price']-min)/(max-min)

data['price_std'] = (data['Price']-avg)/std
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5916\3152931779.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price_norm'] = (data['Price']-min)/(max-min)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5916\3152931779.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price_std'] = (data['Price']-avg)/std

# %%
# %pip install mlflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor, AdaBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
X=df.drop(['Price'],axis=1)
y=df['Price']
x_train,x_test,y_train,y_test  = train_test_split(X,y,test_size=0.2)
models = [ LinearRegression(),Lasso(),Ridge(), RandomForestRegressor(),GradientBoostingRegressor(),AdaBoostRegressor()]
accu=0
best_algo=None
for model in  models:
    model.fit(x_train,y_train)
    train_prediction = model.predict(x_train)
    test_prediction = model.predict(x_test)
    print("\t")
    print(f"{type(model).__name__}")
    print("\t")
    print("****Train****")
    print(f"MSE: {mean_squared_error(y_train,train_prediction)}")
    print(f"R2: {r2_score(y_train,train_prediction)}")
    print("****Test****")
    print(f"MSE: {mean_squared_error(y_test,test_prediction)}")
    print(f"R2: {r2_score(y_test,test_prediction)}")
    print("\n")
    if r2_score(y_test,test_prediction)>accu:
        best_algo =type(model).__name__ 
        accu= r2_score(y_test,test_prediction)
print(best_algo)
# Out:
#
# LinearRegression
#
# ****Train****
# MSE: 12711548.405651366
# R2: 0.4134463044836705
# ****Test****
# MSE: 10808479.891402287
# R2: 0.4493126701635768
#
#
#
# Lasso
#
# ****Train****
# MSE: 12711552.447797518
# R2: 0.4134461179654204
# ****Test****
# MSE: 10808782.97226513
# R2: 0.4492972283259863
#
#
#
# Ridge
#
# ****Train****
# MSE: 12711548.418752272
# R2: 0.4134463038791505
# ****Test****
# MSE: 10808487.622548468
# R2: 0.44931227626505554
#
#
#
# RandomForestRegressor
#
# ****Train****
# MSE: 462678.79971303843
# R2: 0.9786504404382327
# ****Test****
# MSE: 1724662.4046630089
# R2: 0.9121292037330222
#
#
#
# GradientBoostingRegressor
#
# ****Train****
# MSE: 4009785.349203706
# R2: 0.8149749865439662
# ****Test****
# MSE: 3130587.3330250876
# R2: 0.8404979426741898
#
#
#
# AdaBoostRegressor
#
# ****Train****
# MSE: 13391883.63434112
# R2: 0.3820533435442691
# ****Test****
# MSE: 13425428.028415013
# R2: 0.3159803055413979
#
#
# RandomForestRegressor

# %%
data
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            3       0            5            4                7   3897
# 1            1       3            0            1                7   7662
# 2            4       2            1            1                7  13882
# 3            3       3            0            0                7   6218
# 4            3       0            5            0                7  13302
# ...        ...     ...          ...          ...              ...    ...
# 10678        0       3            0            4                7   4107
# 10679        1       3            0            4                7   4145
# 10680        4       0            2            4                7   7229
# 10681       10       0            5            4                7  12648
# 10682        1       2            1            1                7  11753
#
#        Date  Month  Year  Duration_hours  Duration_minutes  Departure_hour  \
# ...

# %%
model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import joblib
joblib.dump(model,'modelpricev1.joblib')
# Out:
# ['modelpricev1.joblib']

# %%
loaded_model=joblib.load('modelpricev1.joblib')
# Test the loaded model
predictions = loaded_model.predict(x_test)
print(predictions)
# Out:
# [ 9045.9         6599.85        5678.         ...  8498.75664286
#  14421.34        5678.        ]

# %%
# %pip install mlflow
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
